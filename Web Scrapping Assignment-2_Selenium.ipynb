# %% [markdown]
# # WEB_SCRAPPING_ASSIGNMENT-2

# %% [markdown]
# # Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location.
# You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10
# jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.
# Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\artia\OneDrive\Documents\selenium\chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys("Bangalore")

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
company_name=[]
job_location=[]
experience_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    name=i.text
    company_name.append(name)
    
experience_tags=driver.find_elements(By.XPATH,'//i[@class="fleft icon-16 lh16 mr-4 naukicon naukicon-experience"]')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({"Job_title":job_title,"Location":job_location,"Company":company_name,"Experience":experience_required})
df
# Out:
#                                            Job_title  \
# 0                                Senior Data Analyst
# 1                                       Data Analyst
# 2  Hiring For Data Analyst (DA)/ Team Lead (TL) -...
# 3  Call For Clinical Data Analyst - Hyd/Bangalore...
# 4                Payroll Transformation Data Analyst
# 5                                    HR Data Analyst
# 6                                Senior Data Analyst
# 7                          Sr. SAP Hana Data Analyst
# 8    Business Execution (Data and Reporting Analyst)
# 9                                       Data Analyst
#
#                                             Location  \
# 0                       Bangalore/Bengaluru, Chennai
# 1                                Bangalore/Bengaluru
# 2  Bangalore/Bengaluru, Kolkata, Hyderabad/Secund...
# 3  Bangalore/Bengaluru, Kolkata, Hyderabad/Secund...
# 4                                Bangalore/Bengaluru
# 5                                Bangalore/Bengaluru
# ...

# %% [markdown]
# # Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location.
# You have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.
# Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
driver=webdriver.Chrome(r"C:\Users\artia\OneDrive\Documents\selenium\chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
Title=[]
Location=[]
Company=[]
experience=[]
Salary=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    T=i.text
    title_tags.append(T)

# %%
print(len(title_tags))
# Out:
# 30

# %%
location_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]:
    L=i.text
    location_tags.append(L)

# %%
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    C=i.text
    company_tags.append(C)

# %%
exp_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]')
for i in exp_tags[0:10]:
    E=i.text
    exp_tags.append(E)

# %%
print(len(title_tags),len(location_tags),len(company_tags),len(exp_tags))
# Out:
# 30 30 30 30

# %%
df=pd.DataFrame({"Title":title_tags,"location":location_tags,"company":company_tags,"Experience":exp_tags})
df
# Out:
#                                                 Title  \
# 0   <selenium.webdriver.remote.webelement.WebEleme...
# 1   <selenium.webdriver.remote.webelement.WebEleme...
# 2   <selenium.webdriver.remote.webelement.WebEleme...
# 3   <selenium.webdriver.remote.webelement.WebEleme...
# 4   <selenium.webdriver.remote.webelement.WebEleme...
# 5   <selenium.webdriver.remote.webelement.WebEleme...
# 6   <selenium.webdriver.remote.webelement.WebEleme...
# 7   <selenium.webdriver.remote.webelement.WebEleme...
# 8   <selenium.webdriver.remote.webelement.WebEleme...
# 9   <selenium.webdriver.remote.webelement.WebEleme...
# 10  <selenium.webdriver.remote.webelement.WebEleme...
# 11  <selenium.webdriver.remote.webelement.WebEleme...
# 12  <selenium.webdriver.remote.webelement.WebEleme...
# 13  <selenium.webdriver.remote.webelement.WebEleme...
# 14  <selenium.webdriver.remote.webelement.WebEleme...
# 15  <selenium.webdriver.remote.webelement.WebEleme...
# ...

# %% [markdown]
# # Q3

# %%
driver=webdriver.Chrome(r"C:\Users\artia\OneDrive\Documents\selenium\chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
role=driver.find_element(By.CLASS_NAME,'suggestor-input')
role.send_keys('Data Scientist')

# %%
search=driver.find_element(By.CLASS_NAME,'qsbSubmit')
search.click()

# %%
title=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title[0:10]:
    t=i.text
    title.append(t)

# %%
loc=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in loc[0:10]:
    l=i.text
    loc.append(l)

# %%
company=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company[0:10]:
    c=i.text
    company.append(c)

# %%
exp=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]')
for i in exp[0:10]:
    e=i.text
    exp.append(e)

# %%
df=pd.DataFrame({"title":title,"loc":loc,"company":company,"exp":exp})
df
# Out:
#                                                 title  \
# 0   <selenium.webdriver.remote.webelement.WebEleme...
# 1   <selenium.webdriver.remote.webelement.WebEleme...
# 2   <selenium.webdriver.remote.webelement.WebEleme...
# 3   <selenium.webdriver.remote.webelement.WebEleme...
# 4   <selenium.webdriver.remote.webelement.WebEleme...
# 5   <selenium.webdriver.remote.webelement.WebEleme...
# 6   <selenium.webdriver.remote.webelement.WebEleme...
# 7   <selenium.webdriver.remote.webelement.WebEleme...
# 8   <selenium.webdriver.remote.webelement.WebEleme...
# 9   <selenium.webdriver.remote.webelement.WebEleme...
# 10  <selenium.webdriver.remote.webelement.WebEleme...
# 11  <selenium.webdriver.remote.webelement.WebEleme...
# 12  <selenium.webdriver.remote.webelement.WebEleme...
# 13  <selenium.webdriver.remote.webelement.WebEleme...
# 14  <selenium.webdriver.remote.webelement.WebEleme...
# 15  <selenium.webdriver.remote.webelement.WebEleme...
# ...

# %% [markdown]
# # Q4: Scrape data of first 100 sunglasses listings on flipkart.com.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\artia\Downloads\chromedriver_win32 (1)\chromedriver.exe")

# %%
driver.get("https://www.flipkart.com/")

# %%
product=driver.find_element(By.CLASS_NAME,'_3704LK')
product.send_keys('sunglasses')

# %%
search=driver.find_element(By.CLASS_NAME,'L0Z3Pu')
search.click()

# %%
brand=[]

# %%
start=0
end=3
for page in range(start,end):
    product=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in product:
        brand.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="ge-49M"]')
    next_button.click()
    time.sleep(3)

# %%
Description=[]

# %%
start=0
end=3
for page in range(start,end):
    des=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in des:
        Description.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="ge-49M"]')
    next_button.click()
    time.sleep(3)

# %%
Price=[]

# %%
start=0
end=3
for page in range(start,end):
    Rate=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in Rate:
        Price.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="ge-49M"]')
    next_button.click()
    time.sleep(3)

# %%
Discount=[]

# %%
start=0
end=3
for page in range(start,end):
    Offer=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
    for i in Offer:
        Discount.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="ge-49M"]')
    next_button.click()
    time.sleep(3)

# %%
print(len(brand),len(Description),len(Price),len(Discount))
# Out:
# 120 120 120 239

# %%
df=pd.DataFrame()
df["BRAND"]=brand[:100]
df["PRODUCT_DESCRIPTION"]=Description[:100]
df["DISCOUNT"]=Discount[:100]
df["PRICE"]=Price[:100]
df
# Out:
#                 BRAND                                PRODUCT_DESCRIPTION  \
# 0        Singco India  Gradient, Toughened Glass Lens, UV Protection ...
# 1        Singco India     UV Protection, Polarized Round Sunglasses (54)
# 2            Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 3   SHAAH COLLECTIONS                UV Protection Round Sunglasses (54)
# 4          LIZA ANGEL      UV Protection Wayfarer Sunglasses (Free Size)
# ..                ...                                                ...
# 95          ROYAL SON  UV Protection, Polarized Wayfarer Sunglasses (54)
# 96             PIRASO              UV Protection Aviator Sunglasses (58)
# 97     kingsunglasses   UV Protection Rectangular Sunglasses (Free Size)
# 98             PIRASO          UV Protection Rectangular Sunglasses (52)
# 99         LIZA ANGEL  UV Protection Rectangular, Retro Square Sungla...
#
#    DISCOUNT PRICE
# 0      ₹179  ₹631
# 1      ₹195  ₹538
# 2      ₹179  ₹799
# ...

# %% [markdown]
# # Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone.

# %%
driver=webdriver.Chrome(r"C:\Users\artia\OneDrive\Documents\selenium\chromedriver.exe")

# %%
driver.get("https://www.flipkart.com/")

# %%
search_item=driver.find_element(By.CLASS_NAME,'_3704LK')
search_item.send_keys('iphone11')

# %%
search_button=driver.find_element(By.CLASS_NAME,'L0Z3Pu')
search_button.click()

# %%
Rating=[]

# %%
start=0
end=13
for page in range(start,end):
    rate=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in rate:
        Rating.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="ge-49M"]')
    next_button.click()
    time.sleep(3)

# %%
Review_summary=[]

# %%
start=0
end=13
for page in range(start,end):
    review=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for i in review:
        Review_summary.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="ge-49M"]')
    next_button.click()
    time.sleep(3)

# %%
Full_review=[]

# %%
start=0
end=13
for page in range(start,end):
    review_F=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in review_F:
        Full_review.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="ge-49M"]')
    next_button.click()
    time.sleep(3)

# %%
df2=pd.DataFrame()
df2["RATINGS"]=Rating[:100]
df2["Review_Summary"]= Review_summary[:100]
df2["FULL_REVIEW"]=Full_review[:100]
df2
# Out:
#    RATINGS                         Review_Summary  \
# 0        5                       Perfect product!
# 1        5                               Terrific
# 2        5                       Iphone 5S review
# 3        4                              Worthless
# 4        5                   Good quality product
# ..     ...                                    ...
# 95       5                       Perfect product!
# 96       5  Good phone but not for the power user
# 97       5                                 Super!
# 98       5                         Simply awesome
# 99       4                 Don't waste your money
#
#                                           FULL_REVIEW
# 0   After using 3 years mobile review. Excellent &...
# 1   I am using the phone for last 5 years and foun...
# 2   Well the iPhone 5S is here ! its the best iPho...
# 3                     There was defect in camera lens
# 4   impressively Nice......\nOne of the greatest i...
# ...

# %% [markdown]
# # Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field.

# %%
driver=webdriver.Chrome(r"C:\Users\artia\OneDrive\Documents\selenium\chromedriver.exe")

# %%
driver.get("https://www.flipkart.com/")

# %%
search_item=driver.find_element(By.CLASS_NAME,'_3704LK')
search_item.send_keys("sneakers")

# %%
Search_button=driver.find_element(By.CLASS_NAME,'L0Z3Pu')
Search_button.click()

# %%
Brand_name=[]

# %%
start=0
end=4
for page in range(start,end):
    brand=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand:
        Brand_name.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="ge-49M"]')
    next_button.click()
    time.sleep(3)

# %%
Description=[]

# %%
start=0
end=4
for page in range(start,end):
    des=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in des:
        Description.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="ge-49M"]')
    next_button.click()
    time.sleep(3)

# %%
Price=[]

# %%
start=0
end=4
for page in range(start,end):
    rate=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in rate:
        Price.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="ge-49M"]')
    next_button.click()
    time.sleep(3)

# %%
Discount=[]

# %%
start=0
end=4
for page in range(start,end):
    offer=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
    for i in offer:
        Discount.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="ge-49M"]')
    next_button.click()
    time.sleep(3)

# %%
df3=pd.DataFrame()
df3['BRANDS']=Brand_name[:100]
df3['DESCRIPTION']=Description[:100]
df3['RRICE']=Price[:100]
df3['DISCOUNT']=Discount[:100]
df3
# Out:
#        BRANDS                                        DESCRIPTION   RRICE  \
# 0          TR                                   Sneakers For Men    ₹338
# 1   EZDEZARIO  Canvas Casual Sneakers For Walking,Running,Gym...    ₹499
# 2      BRUTON               Modern Trendy Shoes Sneakers For Men    ₹470
# 3    RED TAPE                                   Sneakers For Men  ₹1,499
# 4      BRUTON  Lightweight Pack Of 1 Trendy Sneakers Sneakers...    ₹259
# ..        ...                                                ...     ...
# 95  RED CHIEF        Casuals, Canvas, Partywear Sneakers For Men    ₹267
# 96  Deals4you                           Sneaker Sneakers For Men    ₹478
# 97   Magnolia                 Synthetic Leather Sneakers For Men    ₹389
# 98     Rzisbo  Exclusive Affordable Collection of Trendy & St...    ₹449
# 99    BOLTAGO                          Sneakers Sneakers For Men  ₹2,364
#
#    DISCOUNT
# 0   77% off
# 1   71% off
# 2   63% off
# 3   70% off
# 4   56% off
# ...

# %% [markdown]
# # Q7: Go to the link - https://www.myntra.com/shoes Set second Price filter  and Color filter to “Black”, as shown in the below image.

# %%
driver=webdriver.Chrome(r"C:\Users\artia\OneDrive\Documents\selenium\chromedriver.exe")

# %%
driver.get("https://www.myntra.com/shoes")

# %%
price_filter=driver.find_elements(By.XPATH,"//label[@class='common-customCheckbox vertical-filters-label']")
price_filter[7].click()

# %%
color_filter=driver.find_elements(By.XPATH,'//label[@class="common-customCheckbox"]')
color_filter[0].click()

# %%
brand=[]
start=0
end=6
for page in range(start,end):
    brand_name=driver.find_elements(By.XPATH,'//h3[@class="product-brand"]')
    for i in brand_name:
        brand.append(i.text)
    next_button=driver.find_element(By.XPATH,'//li[@class="pagination-number"]')
    next_button.click()
    time.sleep(3)

# %%
Price=[]
start=0
end=6
for page in range(start,end):
    rate=driver.find_elements(By.XPATH,'//span[@class="product-discountedPrice"]')
    for i in rate:
        Price.append(i.text)
    next_button=driver.find_element(By.XPATH,'//li[@class="pagination-number"]')
    next_button.click()
    time.sleep(3)

# %%
description=[]
start=0
end=6
for page in range(start,end):
    des=driver.find_elements(By.XPATH,'//h4[@class="product-product"]')
    for i in des:
        description.append(i.text)
    next_button=driver.find_element(By.XPATH,'//li[@class="pagination-number"]')
    next_button.click()
    time.sleep(3)

# %%
df4=pd.DataFrame()
df4["BRAND_NAME"]=brand[:100]
df4["DESCRIPTION"]=description[:100]
df4["PRICE"]=Price[:100]
df4
# Out:
#          BRAND_NAME                        DESCRIPTION      PRICE
# 0          Skechers          Men Go Walk Walking Shoes   Rs. 6374
# 1          Skechers          Men GO WALK - TERRA Shoes   Rs. 8499
# 2              Puma        Men Fuse 2.0 Training Shoes   Rs. 6399
# 3            ADIDAS      Men 4DFWD_Pulse Running Shoes  Rs. 11199
# 4          Skechers     Men Go Run Hyper Burst Running   Rs. 7224
# ..              ...                                ...        ...
# 95  PUMA Motorsport            Men PL RDG Cat Sneakers   Rs. 6999
# 96             Puma              Women Enlighten Shoes   Rs. 5999
# 97           ADIDAS           Women EQ21 Running Shoes   Rs. 7199
# 98     Hush Puppies  Men Solid Leather Formal Slip-Ons   Rs. 7999
# 99   Tommy Hilfiger               Men Leather Sneakers   Rs. 6399
#
# [100 rows x 3 columns]

# %% [markdown]
# # Q8: Go to webpage https://www.amazon.in/ Enter “Laptop” in the search field and then click the search icon.Then set CPU Type filter to “Intel Core i7” as shown in the below image:

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\artia\OneDrive\Documents\selenium\chromedriver.exe")

# %%
url="https://www.amazon.in/"
driver.get(url)

# %%
driver.maximize_window()

# %%
search_col=driver.find_element(By.XPATH,"//input[@class='nav-input nav-progressive-attribute']")
search_col.send_keys('laptop')

# %%
search_button=driver.find_elements(By.XPATH,"//input[@class='nav-input nav-progressive-attribute']")

# %%
search_button[1].click()

# %%
title_el=driver.find_elements(By.XPATH,"//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']")
title=[]
for i in title_el[:10]:
    title.append(i.text)
title
# Out:
# ['Acer Extensa 15 Lightweight Laptop 11th Gen Intel Core i3 Processor with 15.6" (39.6 cms) Full HD Display- (8 GB RAM/256GB SSD/Windows 11 Home/Intel UHD Graphics /1.7Kg/Black) EX215-54',
#  'HP 15s, 11th Gen Intel Core i3, 8GB RAM/512GB SSD 15.6-inch(39.6 cm) Micro-Edge Anti-Glare FHD Laptop/Alexa Built-in/Win 11/Intel UHD Graphics/Dual Speakers/ MS Office 2021/1.69 Kg, 15s-fr2511TU',
#  'ASUS Vivobook 15, 15.6-inch (39.62 cms) FHD, AMD Ryzen 3 3200U, Thin and Laptop (8GB/512GB SSD/Integrated Graphics/Windows 11/Office 2021/Silver/1.68 kg), X512DA-BQ311WS',
#  '(Renewed) Lenovo Thinkpad E480 7th Gen Intel Core i3 Thin & Light HD Laptop (8 GB DDR4 RAM/500 GB HDD/14" (35.6 cm)/Windows 10/WiFi/Bluetooth 4.0/Webcam/Intel HD Graphics)',
#  'ASUS VivoBook 15 (2021), 15.6-inch (39.62 cm) HD, Dual Core Intel Celeron N4020, Thin and Light Laptop (4GB RAM/256GB SSD/Integrated Graphics/Windows 11 Home/Transparent Silver/1.8 Kg), X515MA-BR011W',
# ...

# %%
price_el=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
price=[]
for i in price_el[:10]:
    price.append(i.text)
price
# Out:
# ['38,990',
#  '42,990',
#  '37,999',
#  '32,990',
#  '38,990',
#  '26,990',
#  '19,599',
#  '25,990',
#  '21,990',
#  '32,390']

# %%
url2=driver.find_elements(By.XPATH,'//a[@class="a-link-normal a-text-normal"]')

rating_url=[]
for i in url2[:10]:
    rating_url.append(i.get_attribute('href'))
rating_url
# Out:
# ['https://aax-eu.amazon.in/x/c/RAp9brui6jpnjBPQup926C0AAAGDmET-3QMAAAH2AQBOL0EgICAgICAgICAgICBOL0EgICAgICAgICAgICCjy1eb/https://www.amazon.in/dp/B0B93HNW44?pd_rd_i=B0B93HNW44&pf_rd_p=d882f7bc-c7c5-4887-b939-1af6f91cc448&pf_rd_r=QWEX2NEQYH0MJXNCS2BR&pd_rd_wg=p3f6R&pd_rd_w=Vpoks&pd_rd_r=0c1b1ada-badd-4ad2-a31f-b06da771f17a',
#  'https://aax-eu.amazon.in/x/c/RMutKYhY9v3sp0d5mxYu5rsAAAGDmET-3gMAAAH2AQBOL0EgICAgICAgICAgICBOL0EgICAgICAgICAgICD6MC3h/https://www.amazon.in/dp/B0B93HNW44?pd_rd_i=B0B93HNW44&pf_rd_p=d85289ff-7b04-49b7-8f39-1b9f677610ec&pf_rd_r=QWEX2NEQYH0MJXNCS2BR&pd_rd_wg=KOLTB&pd_rd_w=tXNbv&pd_rd_r=ed9fb555-204b-45a7-819b-99b9d805c7b1']

# %%
rating=[]
for i in rating_url[:10]:
    driver.get(i)
    time.sleep(3)
    try:
        
        ratings = driver.find_element(By.XPATH,".//span[@class='a-icon-alt']/..")
        ratings = ratings.get_attribute('innerHTML').split(">")[1].split(" ")[0]
        rating.append(ratings)
    except:
        
        
        rating.append("00")
rating
# Out:
# ['5.0', '5.0']

# %%
laptop_df=pd.DataFrame()
laptop_df['TITLE']=title[:10]
laptop_df['PRICE']=price[:10]
laptop_df
# Out:
#                                                TITLE   PRICE
# 0  Acer Extensa 15 Lightweight Laptop 11th Gen In...  38,990
# 1  HP 15s, 11th Gen Intel Core i3, 8GB RAM/512GB ...  42,990
# 2  ASUS Vivobook 15, 15.6-inch (39.62 cms) FHD, A...  37,999
# 3  (Renewed) Lenovo Thinkpad E480 7th Gen Intel C...  32,990
# 4  ASUS VivoBook 15 (2021), 15.6-inch (39.62 cm) ...  38,990
# 5  Lenovo IdeaPad Slim 1 AMD Ryzen 3 3250U 15.6" ...  26,990
# 6  ASUS Vivobook 15, 15.6" (39.62 cm) FHD, AMD Du...  19,599
# 7  (Renewed) Dell Latitude E5470 Intel Core i5 6t...  25,990
# 8  Lenovo IdeaPad Slim 1 Intel Celeron N4020 4th ...  21,990
# 9  Lenovo IdeaPad Slim 3 Intel Celeron N4020 4th ...  32,390

# %%
#there is some problem in applying filter
#there is problem scrapping the ratings data.

# %% [markdown]
# # Q10: Write a python program to scrape the salary data for Data Scientist designation.You have to scrape Company name, Number of salaries, Average salary, Minsalary, Max Salary.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\artia\OneDrive\Documents\selenium\chromedriver.exe")

# %%
driver.get("https://www.ambitionbox.com/")

# %%
salary=driver.find_element(By.XPATH,'/html/body/div/div/div/div[1]/header/nav/ul/li[3]')
salary.click()

# %%
search_sal=driver.find_element(By.XPATH,'/html/body/div/div/div/div[1]/header/nav/ul/li[3]/div/ul/li[1]/div/div[2]')
search_sal.click()

# %%
job=driver.find_element(By.XPATH,'/html/body/div/div/div/main/section[1]/div[2]/div[1]/span/input')
job.send_keys("Data Scientist")
job.click()

# %%
job=driver.find_element(By.XPATH,'/html/body/div/div/div/main/section[1]/div[2]/div[1]/span/div/div/div[1]')
job.click()

# %%
company_name=driver.find_elements(By.XPATH,'//div[@class="company-info"]')
company=[]
for i in company_name[:10]:
    c=i.text
    company.append(c)
    
experience_req=driver.find_elements(By.XPATH,'//div[@class="sbold-list-header"]')
experience=[]
for i in experience_req[:10]:
    E=i.text
    experience.append(E)
    
sal_rec=driver.find_elements(By.XPATH,'//span[@class="datapoints"]')
Record=[]
for i in sal_rec[:10]:
    E=i.text
    Record.append(E)
   
Avg=driver.find_elements(By.XPATH,'//div[@class="salary-values"]')
Avg_Sal=[]
for i in Avg[:10]:
    E=i.text
    Avg_Sal.append(E)
    
minimum=driver.find_elements(By.XPATH,'//div[@class="value body-medium"]')
MIN=[]
for i in minimum[:10]:
    m=i.text
    MIN.append(m)
    
maximum=driver.find_elements(By.XPATH,'//div[@class="value body-medium"]')
MAX=[]
for i in maximum[:10]:
    M=i.text
    MAX.append(M)

# %%
df6=pd.DataFrame()
df6["COMPANY"]=company
df6["EXPERIENCE"]=experience
df6["SALARY_RECORD"]=Record
df6["AVERAGE_SALARY"]=Avg_Sal
df6["MINIMUN_SALARY"]=MIN
df6["MAXIMUM_SALARY"]=MAX
df6
# Out:
#                                              COMPANY  \
# 0  Walmart\nData Scientist Salary\n3-4 yrs experi...
# 1  Ab Inbev\nData Scientist Salary\n2-4 yrs exper...
# 2  Optum\nData Scientist Salary\n2-4 yrs experien...
# 3  ZS\nData Scientist Salary\n1-2 yrs experience ...
# 4  Fractal Analytics\nData Scientist Salary\n2-4 ...
# 5  Sigmoid Analytics\nData Scientist Salary\n1 yr...
# 6  Tiger Analytics\nData Scientist Salary\n2-4 yr...
# 7  Legato Health Technologies\nData Scientist Sal...
# 8  HSBC\nData Scientist Salary\n4 yrs experience ...
# 9  Tredence\nData Scientist Salary\n3 yrs experie...
#
#                                    EXPERIENCE            SALARY_RECORD  \
# 0   3-4 yrs experience (based on 24 salaries)   (based on 24 salaries)
# 1   2-4 yrs experience (based on 59 salaries)   (based on 59 salaries)
# 2   2-4 yrs experience (based on 49 salaries)   (based on 49 salaries)
# 3   1-2 yrs experience (based on 35 salaries)   (based on 35 salaries)
# ...

# %% [markdown]
# # THE END
